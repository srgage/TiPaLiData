# %%
import csv
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
class DataPrep:
    def __init__(self, folder='.', image_size=100, camera_h_fov=72.2, camera_h_res=3264, 
                 in_csv='data.csv', out_csv='final_data.csv', prefix='final_'):
        self.folder = folder
        self.image_size = image_size
        self.camera_fov_per_pixel = camera_h_fov/camera_h_res
        self.csv_in_path = os.path.join(folder, in_csv)
        self.csv_out_path = os.path.join(folder, out_csv)
        self.prefix = prefix
        self.headers = []
        self.in_data = []
        self.out_data = []
        self._readData()

    def _readData(self):
        self.in_data = []
        with open(self.csv_in_path, 'r') as file:
            csv_reader = csv.reader(file)
            self.headers = None
            for row in csv_reader:
                if self.headers is None:
                    self.headers = row
                else:
                    self.in_data.append(row)
    
    def _writeData(self):
        with open(self.csv_out_path, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(self.headers + ['SAMPLE_FOV'])
            writer.writerows(self.out_data)

    def _processImage(self, image_color):
        # convert the image to grayscale
        image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

        # find the threshold value
        tv = self._findTheshold(image_gray)

        # threshold the image
        image_thresh = cv2.threshold(image_gray, tv, 255, cv2.THRESH_BINARY)[1]

        # get a mask for the feature
        mask = self._getFeatureMask(image_thresh)
        if mask is None:
            return None, None

        # normalize the intensity within the masked area and zero elsewhere
        image_norm = self._normalizeIntensity(image_gray, mask)
        if image_norm is None:
            return None, None

        # find the centroid of the feature and the bounding extents
        center_x, center_y, min_x, min_y, max_x, max_y = self._findCentroidAndBounds(mask)
        
        # calculate a size that can contain the centered image extents
        size = int(2 * max(center_y - min_y, max_y - center_y, center_x - min_x, max_x - center_x))
        # create a blank image
        image_centered = np.zeros((size, size), dtype=np.uint8)
        # crop to extents
        image_crop = image_norm[int(min_y):int(max_y),
                                int(min_x):int(max_x)]
        # determine the offsets to position the cropped image with the centroid in the center
        offset_x = int(min_x - (center_x - size/2))
        offset_y = int(min_y - (center_y - size/2))
        # paste into blank image
        image_centered[offset_y:offset_y+image_crop.shape[0], 
                       offset_x:offset_x+image_crop.shape[1]] = image_crop
        
        # resize the image
        image_resize = cv2.resize(image_centered, (self.image_size, self.image_size))
        # determine the actual fov for the sample
        sample_fov = self.camera_fov_per_pixel * size
        return image_resize, sample_fov
        
    def _findTheshold(self, image):
        # Create an elliptical, arc-shaped mask to sample around the edge of the plate.
        # Arc is inset two pixels from the edges and has a thickness of two,
        # so it should not touch the 0 value area.
        # Skips a 90 degree arc at the top of the image since vertical features of
        # the object may protrude into this area when tilt is close to zero.
        height = image.shape[0]
        width  = image.shape[1]
        mask = np.zeros((height, width), dtype=np.uint8)
        cv2.ellipse(mask, (width//2, height//2), (width//2 - 2, height//2 - 2), 0, -45, 180+45, 255, 2)
        
        # find max pixel values around edge of ellipse arc
        minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(image, mask=mask)
    
        # threshold value is max pixel value + 2
        return int(maxVal + 2)

    def _normalizeIntensity(self, image, mask):
        # normalize the image intensity
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(image, mask=mask)
        if max_val - min_val < 1:
            return None
        # real data values should be 1 to 255
        image_norm = np.clip((254/(max_val-min_val))*(image.astype(np.float32) - min_val) + 1, 0, 255).astype(np.uint8)
        # background will have value 0
        image_masked = cv2.bitwise_and(image_norm, image_norm, mask=mask)
        return image_masked

    def _getFeatureMask(self, image_thresh):
        # Find the largest contiguous closed region (ignore holes)
        # First find external contours only
        contours, hierarchy = cv2.findContours(image_thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if len(contours) < 1:
            return None
        # Find the region with the longest perimeter, assume the rest is noise
        max_index = -1
        max_perim = -1
        for i in range(len(contours)):
            perim = len(contours[i])
            if perim > max_perim:
                max_perim = perim
                max_index = i
        # Create a mask for the feature
        mask = np.zeros(image_thresh.shape[:2], dtype=np.uint8)
        cv2.drawContours(mask, [contours[max_index]], -1, 255, -1)
        return mask

    def _findCentroidAndBounds(self, mask):
        # find the connected components in the mask to get the centroid and extents
        numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(mask, 4, cv2.CV_32S)
        if numLabels > 2:
            print("WARNING: more than one non-background region found")
        center_x = centroids[1][0]
        center_y = centroids[1][1]
        min_x = stats[1][0]
        min_y = stats[1][1]
        max_x = stats[1][0] + stats[1][2]
        max_y = stats[1][1] + stats[1][3]
        return center_x, center_y, min_x, min_y, max_x, max_y

    def processData(self):
        self.out_data = []
        for row in self.in_data:
            filename = row[0]
            path = os.path.join(self.folder, filename)
            image_color = cv2.imread(path)
            has_error = False
            try:
                image_proc, sample_fov = self._processImage(image_color)
            except:
                has_error = True
            if has_error:
                print(f'Skipping {filename}, error encountered during processing')
                continue
            if image_proc is None:
                print(f'Skipping {filename}, could not process')
                continue
            cv2.imwrite(os.path.join(self.folder, self.prefix + filename), image_proc)
            self.out_data.append([self.prefix + filename] + row[1:] + [sample_fov])
        self._writeData()

# %%
dp = DataPrep(folder='ScienceFairData')

# %%
dp.processData()
# Out:
# [ WARN:0@4002.830] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.846] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0002.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.846] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0003.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0005.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0006.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.847] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0014.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.848] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0017.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0018.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0019.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0020.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0021.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.849] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0022.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0024.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0025.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0026.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0027.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0028.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0029.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.850] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0030.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0031.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0032.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0033.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0034.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0035.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0036.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0037.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.851] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0038.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0039.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0041.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0042.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0043.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.852] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0044.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0045.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0046.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0047.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0048.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0049.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0051.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0052.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.853] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0054.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0055.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0056.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0057.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0058.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0059.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0060.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.854] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0061.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0062.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0063.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0064.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0065.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0066.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0067.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0068.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0069.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.855] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0070.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0071.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0072.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0073.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0074.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0076.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0077.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0078.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.856] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0079.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0080.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0081.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0082.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0083.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0084.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0085.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0086.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0087.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.857] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0088.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0089.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0090.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0091.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0092.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0093.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.858] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0094.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0095.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0096.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0097.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0098.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0099.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0100.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0101.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0102.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.859] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0103.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0104.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0105.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0106.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0107.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0108.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0109.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0110.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0111.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0112.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.860] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0113.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.861] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0114.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.861] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0115.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.861] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0116.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.861] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0117.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.861] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0118.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0119.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0120.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0121.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0122.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0123.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0124.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0125.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.862] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0126.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0127.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0128.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0129.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_001_0130.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0002.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0003.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0005.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0006.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.863] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0014.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.864] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0017.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0018.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0019.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0020.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0021.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0022.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0024.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0025.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.865] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0026.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0027.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0028.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0029.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0030.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0031.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0032.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0033.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0034.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0035.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0036.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0037.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0038.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.866] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0039.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0041.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0042.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0043.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0044.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0045.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0046.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0047.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0048.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0049.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0051.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.867] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0052.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0054.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0055.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0056.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0057.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0058.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0059.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.868] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0060.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0061.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0062.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0063.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0064.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0065.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0066.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0067.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0068.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0069.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0070.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0071.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0072.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0073.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.869] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0074.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_004_0076.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0002.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0003.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0005.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0006.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.870] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0014.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0017.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0018.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0019.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.871] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0020.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0021.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0022.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0024.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0025.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0026.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0027.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0028.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0029.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0030.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0031.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0032.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0033.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.872] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0034.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0035.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0036.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0037.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0038.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0039.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0041.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0042.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0043.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.873] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0044.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0045.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0046.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0047.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0048.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0049.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0051.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.874] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0052.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0054.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0055.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0056.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0057.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0058.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0059.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0060.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0061.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0062.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.875] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0063.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0064.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0065.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0066.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0067.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0068.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0069.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0070.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.876] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0071.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0072.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0073.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0074.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0076.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0077.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0078.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0079.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0080.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.877] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0081.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0082.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0083.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0084.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0085.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0086.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0087.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0088.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0089.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0090.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0091.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0092.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0093.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0094.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0095.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.878] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0096.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0097.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0098.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0099.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0100.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0101.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0102.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0103.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0104.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0105.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0106.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.879] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0107.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0108.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0109.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0110.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0111.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0112.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0113.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0114.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0115.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4002.880] global loadsave.cpp:241 findDecoder imread_('ScienceFairData/test_010_0116.jpg'): can't open/read file: check file path/integrity
# ...
# Skipping leaf_G_2_2415.jpg, error encountered during processing
# Skipping leaf_G_2_2416.jpg, error encountered during processing
# Skipping leaf_G_2_2417.jpg, error encountered during processing
# Skipping leaf_G_2_2418.jpg, error encountered during processing
# Skipping leaf_G_2_2419.jpg, error encountered during processing
# Skipping leaf_G_2_2420.jpg, error encountered during processing
# Skipping leaf_G_2_2421.jpg, error encountered during processing
# Skipping leaf_G_2_2422.jpg, error encountered during processing
# Skipping leaf_G_2_2423.jpg, error encountered during processing
# Skipping leaf_G_2_2424.jpg, error encountered during processing
# Skipping leaf_G_2_2425.jpg, error encountered during processing
# Skipping leaf_G_2_2426.jpg, error encountered during processing
# Skipping leaf_G_2_2427.jpg, error encountered during processing
# Skipping leaf_G_2_2428.jpg, error encountered during processing
# Skipping leaf_G_2_2429.jpg, error encountered during processing
# Skipping leaf_G_2_2430.jpg, error encountered during processing
# Skipping leaf_G_2_2431.jpg, error encountered during processing
# Skipping leaf_G_2_2432.jpg, error encountered during processing
# Skipping leaf_G_2_2433.jpg, error encountered during processing
# Skipping leaf_G_2_2434.jpg, error encountered during processing
# Skipping leaf_G_2_2435.jpg, error encountered during processing
# Skipping leaf_G_2_2436.jpg, error encountered during processing
# Skipping leaf_G_2_2437.jpg, error encountered during processing
# Skipping leaf_G_2_2438.jpg, error encountered during processing
# Skipping leaf_G_2_2439.jpg, error encountered during processing
# Skipping leaf_G_2_2440.jpg, error encountered during processing
# Skipping leaf_G_2_2441.jpg, error encountered during processing
# Skipping leaf_G_2_2442.jpg, error encountered during processing
# Skipping leaf_G_2_2443.jpg, error encountered during processing
# Skipping leaf_G_2_2444.jpg, error encountered during processing
# Skipping leaf_G_2_2445.jpg, error encountered during processing
# Skipping leaf_G_2_2446.jpg, error encountered during processing
# Skipping leaf_G_2_2447.jpg, error encountered during processing
# Skipping leaf_G_2_2448.jpg, error encountered during processing
# Skipping leaf_G_2_2449.jpg, error encountered during processing
# Skipping leaf_G_2_2450.jpg, error encountered during processing
# Skipping leaf_G_2_2451.jpg, error encountered during processing
# Skipping leaf_G_2_2452.jpg, error encountered during processing
# Skipping leaf_G_2_2453.jpg, error encountered during processing
# Skipping leaf_G_2_2454.jpg, error encountered during processing
# Skipping leaf_G_2_2455.jpg, error encountered during processing
# Skipping leaf_G_2_2456.jpg, error encountered during processing
# Skipping leaf_G_2_2457.jpg, error encountered during processing
# Skipping leaf_G_2_2458.jpg, error encountered during processing
# Skipping leaf_G_2_2459.jpg, error encountered during processing
# Skipping leaf_G_2_2460.jpg, error encountered during processing
# Skipping leaf_G_2_2461.jpg, error encountered during processing
# Skipping leaf_G_2_2462.jpg, error encountered during processing
# Skipping leaf_G_2_2463.jpg, error encountered during processing
# Skipping leaf_G_2_2464.jpg, error encountered during processing
# Skipping leaf_G_2_2465.jpg, error encountered during processing
# Skipping leaf_G_2_2466.jpg, error encountered during processing
# Skipping leaf_G_2_2467.jpg, error encountered during processing
# Skipping leaf_G_2_2468.jpg, error encountered during processing
# Skipping leaf_G_2_2469.jpg, error encountered during processing
# Skipping leaf_G_2_2470.jpg, error encountered during processing
# Skipping leaf_G_2_2471.jpg, error encountered during processing
# Skipping leaf_G_2_2472.jpg, error encountered during processing
# Skipping leaf_G_2_2473.jpg, error encountered during processing
# Skipping leaf_G_2_2474.jpg, error encountered during processing
# Skipping leaf_G_2_2475.jpg, error encountered during processing
# Skipping leaf_G_2_2476.jpg, error encountered during processing
# Skipping leaf_G_2_2477.jpg, error encountered during processing
# Skipping leaf_G_2_2478.jpg, error encountered during processing
# Skipping leaf_G_2_2479.jpg, error encountered during processing
# Skipping leaf_G_2_2480.jpg, error encountered during processing
# Skipping leaf_G_2_2481.jpg, error encountered during processing
# Skipping leaf_G_2_2482.jpg, error encountered during processing
# Skipping leaf_G_2_2483.jpg, error encountered during processing
# Skipping leaf_G_2_2484.jpg, error encountered during processing
# Skipping leaf_G_2_2485.jpg, error encountered during processing
# Skipping leaf_G_2_2486.jpg, error encountered during processing
# Skipping leaf_G_2_2487.jpg, error encountered during processing
# Skipping leaf_G_2_2488.jpg, error encountered during processing
# Skipping leaf_G_2_2489.jpg, error encountered during processing
# Skipping leaf_G_2_2490.jpg, error encountered during processing
# Skipping leaf_G_2_2491.jpg, error encountered during processing
# Skipping leaf_G_2_2492.jpg, error encountered during processing
# Skipping leaf_G_2_2493.jpg, error encountered during processing
# Skipping leaf_G_2_2494.jpg, error encountered during processing
# Skipping leaf_G_2_2495.jpg, error encountered during processing
# Skipping leaf_G_2_2496.jpg, error encountered during processing
# Skipping leaf_G_2_2497.jpg, error encountered during processing
# Skipping leaf_G_2_2498.jpg, error encountered during processing
# Skipping leaf_G_2_2499.jpg, error encountered during processing
# Skipping leaf_G_2_2500.jpg, error encountered during processing
# Skipping leaf_G_2_2501.jpg, error encountered during processing
# Skipping leaf_G_2_2502.jpg, error encountered during processing
# Skipping leaf_G_2_2503.jpg, error encountered during processing
# Skipping leaf_G_2_2504.jpg, error encountered during processing
# Skipping leaf_G_2_2505.jpg, error encountered during processing
# Skipping leaf_G_2_2506.jpg, error encountered during processing
# Skipping leaf_G_2_2507.jpg, error encountered during processing
# Skipping leaf_G_2_2508.jpg, error encountered during processing
# Skipping leaf_G_2_2509.jpg, error encountered during processing
# Skipping leaf_G_2_2510.jpg, error encountered during processing
# Skipping leaf_G_2_2511.jpg, error encountered during processing
# Skipping leaf_G_2_2512.jpg, error encountered during processing
# Skipping leaf_G_2_2513.jpg, error encountered during processing
# Skipping leaf_G_2_2514.jpg, error encountered during processing
# Skipping leaf_G_2_2515.jpg, error encountered during processing
# Skipping leaf_G_2_2516.jpg, error encountered during processing
# Skipping leaf_G_2_2517.jpg, error encountered during processing
# Skipping leaf_G_2_2518.jpg, error encountered during processing
# Skipping leaf_G_2_2519.jpg, error encountered during processing
# Skipping leaf_G_2_2520.jpg, error encountered during processing
# Skipping leaf_G_2_2521.jpg, error encountered during processing
# Skipping leaf_G_2_2522.jpg, error encountered during processing
# Skipping leaf_G_2_2523.jpg, error encountered during processing
# Skipping leaf_G_2_2524.jpg, error encountered during processing
# Skipping leaf_G_2_2525.jpg, error encountered during processing
# Skipping leaf_G_2_2526.jpg, error encountered during processing
# Skipping leaf_G_2_2527.jpg, error encountered during processing
# Skipping leaf_G_2_2528.jpg, error encountered during processing
# Skipping leaf_G_2_2529.jpg, error encountered during processing
# Skipping leaf_G_2_2530.jpg, error encountered during processing
# Skipping leaf_G_2_2531.jpg, error encountered during processing
# Skipping leaf_G_2_2532.jpg, error encountered during processing
# Skipping leaf_G_2_2533.jpg, error encountered during processing
# Skipping leaf_G_2_2534.jpg, error encountered during processing
# Skipping leaf_G_2_2535.jpg, error encountered during processing
# Skipping leaf_G_2_2536.jpg, error encountered during processing
# Skipping leaf_G_2_2537.jpg, error encountered during processing
# Skipping leaf_G_2_2538.jpg, error encountered during processing
# Skipping leaf_G_2_2539.jpg, error encountered during processing
# Skipping leaf_G_2_2540.jpg, error encountered during processing
# Skipping leaf_G_2_2541.jpg, error encountered during processing
# Skipping leaf_G_2_2542.jpg, error encountered during processing
# Skipping leaf_G_2_2543.jpg, error encountered during processing
# Skipping leaf_G_2_2544.jpg, error encountered during processing
# Skipping leaf_G_2_2545.jpg, error encountered during processing
# Skipping leaf_G_2_2546.jpg, error encountered during processing
# Skipping leaf_G_2_2547.jpg, error encountered during processing
# Skipping leaf_G_2_2548.jpg, error encountered during processing
# Skipping leaf_G_2_2549.jpg, error encountered during processing
# Skipping leaf_G_2_2550.jpg, error encountered during processing
# Skipping leaf_G_2_2551.jpg, error encountered during processing
# Skipping leaf_G_2_2552.jpg, error encountered during processing
# Skipping leaf_G_2_2553.jpg, error encountered during processing
# Skipping leaf_G_2_2554.jpg, error encountered during processing
# Skipping leaf_G_2_2555.jpg, error encountered during processing
# Skipping leaf_G_2_2556.jpg, error encountered during processing
# Skipping leaf_G_2_2557.jpg, error encountered during processing
# Skipping leaf_G_2_2558.jpg, error encountered during processing
# Skipping leaf_G_2_2559.jpg, error encountered during processing
# Skipping leaf_G_2_2560.jpg, error encountered during processing
# Skipping leaf_G_2_2561.jpg, error encountered during processing
# Skipping leaf_G_2_2562.jpg, error encountered during processing
# Skipping leaf_G_2_2563.jpg, error encountered during processing
# Skipping leaf_G_2_2564.jpg, error encountered during processing
# Skipping leaf_G_2_2565.jpg, error encountered during processing
# Skipping leaf_G_2_2566.jpg, error encountered during processing
# Skipping leaf_G_2_2567.jpg, error encountered during processing
# Skipping leaf_G_2_2568.jpg, error encountered during processing
# Skipping leaf_G_2_2569.jpg, error encountered during processing
# Skipping leaf_G_2_2570.jpg, error encountered during processing
# Skipping leaf_G_2_2571.jpg, error encountered during processing
# Skipping leaf_G_2_2572.jpg, error encountered during processing
# Skipping leaf_G_2_2573.jpg, error encountered during processing
# Skipping leaf_G_2_2574.jpg, error encountered during processing
# Skipping leaf_G_2_2575.jpg, error encountered during processing
# Skipping leaf_G_2_2576.jpg, error encountered during processing
# Skipping leaf_G_2_2577.jpg, error encountered during processing
# Skipping leaf_G_2_2578.jpg, error encountered during processing
# Skipping leaf_G_2_2579.jpg, error encountered during processing
# Skipping leaf_G_2_2580.jpg, error encountered during processing
# Skipping leaf_G_2_2581.jpg, error encountered during processing
# Skipping leaf_G_2_2582.jpg, error encountered during processing
# Skipping leaf_G_2_2583.jpg, error encountered during processing
# Skipping leaf_G_2_2584.jpg, error encountered during processing
# Skipping leaf_G_2_2585.jpg, error encountered during processing
# Skipping leaf_G_2_2586.jpg, error encountered during processing
# Skipping leaf_G_2_2587.jpg, error encountered during processing
# Skipping leaf_G_2_2588.jpg, error encountered during processing
# Skipping leaf_G_2_2589.jpg, error encountered during processing
# Skipping leaf_G_2_2590.jpg, error encountered during processing
# Skipping leaf_G_2_2591.jpg, error encountered during processing
# Skipping leaf_G_2_2592.jpg, error encountered during processing
# Skipping leaf_G_2_2593.jpg, error encountered during processing
# Skipping leaf_G_2_2594.jpg, error encountered during processing
# Skipping leaf_G_2_2595.jpg, error encountered during processing
# Skipping leaf_G_2_2596.jpg, error encountered during processing
# Skipping leaf_G_2_2597.jpg, error encountered during processing
# Skipping leaf_G_2_2598.jpg, error encountered during processing
# Skipping leaf_G_2_2599.jpg, error encountered during processing
# Skipping leaf_G_2_2600.jpg, error encountered during processing
# Skipping leaf_G_2_2601.jpg, error encountered during processing
# Skipping leaf_G_2_2602.jpg, error encountered during processing
# Skipping leaf_G_2_2603.jpg, error encountered during processing
# Skipping leaf_G_2_2604.jpg, error encountered during processing
# Skipping leaf_G_2_2605.jpg, error encountered during processing
# Skipping leaf_G_2_2606.jpg, error encountered during processing
# Skipping leaf_G_2_2607.jpg, error encountered during processing
# Skipping leaf_G_2_2608.jpg, error encountered during processing
# Skipping leaf_G_2_2609.jpg, error encountered during processing
# Skipping leaf_G_2_2610.jpg, error encountered during processing
# Skipping leaf_G_2_2611.jpg, error encountered during processing
# Skipping leaf_G_2_2612.jpg, error encountered during processing
# Skipping leaf_G_2_2613.jpg, error encountered during processing
# Skipping leaf_G_2_2614.jpg, error encountered during processing
# Skipping leaf_G_2_2615.jpg, error encountered during processing
# Skipping leaf_G_2_2616.jpg, error encountered during processing
# Skipping leaf_G_2_2617.jpg, error encountered during processing
# Skipping leaf_G_2_2618.jpg, error encountered during processing
# Skipping leaf_G_2_2619.jpg, error encountered during processing
# Skipping leaf_G_2_2620.jpg, error encountered during processing
# Skipping leaf_G_2_2621.jpg, error encountered during processing
# Skipping leaf_G_2_2622.jpg, error encountered during processing
# Skipping leaf_G_2_2623.jpg, error encountered during processing
# Skipping leaf_G_2_2624.jpg, error encountered during processing
# Skipping leaf_G_2_2625.jpg, error encountered during processing
# Skipping leaf_G_2_2626.jpg, error encountered during processing
# Skipping leaf_G_2_2627.jpg, error encountered during processing
# Skipping leaf_G_2_2628.jpg, error encountered during processing
# Skipping leaf_G_2_2629.jpg, error encountered during processing
# Skipping leaf_G_2_2630.jpg, error encountered during processing
# Skipping leaf_G_2_2631.jpg, error encountered during processing
# Skipping leaf_G_2_2632.jpg, error encountered during processing
# Skipping leaf_G_2_2633.jpg, error encountered during processing
# Skipping leaf_G_2_2634.jpg, error encountered during processing
# Skipping leaf_G_2_2635.jpg, error encountered during processing
# Skipping leaf_G_2_2636.jpg, error encountered during processing
# Skipping leaf_G_2_2637.jpg, error encountered during processing
# Skipping leaf_G_2_2638.jpg, error encountered during processing
# Skipping leaf_G_2_2639.jpg, error encountered during processing
# Skipping leaf_G_2_2640.jpg, error encountered during processing
# Skipping leaf_G_2_2641.jpg, error encountered during processing
# Skipping leaf_G_2_2642.jpg, error encountered during processing
# Skipping leaf_G_2_2643.jpg, error encountered during processing
# Skipping leaf_G_2_2644.jpg, error encountered during processing
# Skipping leaf_G_2_2645.jpg, error encountered during processing
# Skipping leaf_G_2_2646.jpg, error encountered during processing
# Skipping leaf_G_2_2647.jpg, error encountered during processing
# Skipping leaf_G_2_2648.jpg, error encountered during processing
# Skipping leaf_G_2_2649.jpg, error encountered during processing
# Skipping leaf_G_2_2650.jpg, error encountered during processing
# Skipping leaf_G_2_2651.jpg, error encountered during processing
# Skipping leaf_G_2_2652.jpg, error encountered during processing
# Skipping leaf_G_2_2653.jpg, error encountered during processing
# Skipping leaf_G_2_2654.jpg, error encountered during processing
# Skipping leaf_G_2_2655.jpg, error encountered during processing
# Skipping leaf_G_2_2656.jpg, error encountered during processing
# Skipping leaf_G_2_2657.jpg, error encountered during processing
# Skipping leaf_G_2_2658.jpg, error encountered during processing
# Skipping leaf_G_2_2659.jpg, error encountered during processing
# Skipping leaf_G_2_2660.jpg, error encountered during processing
# Skipping leaf_G_2_2661.jpg, error encountered during processing
# Skipping leaf_G_2_2662.jpg, error encountered during processing
# Skipping leaf_G_2_2663.jpg, error encountered during processing
# Skipping leaf_G_2_2664.jpg, error encountered during processing
